# %% [markdown]
# # 🎮 Workshop Grafika Komputer
# ## Pertemuan 3 — Dasar Grafika 2D dengan p5.js
#
# **Program Studi:** D4 Teknologi Game
# **Platform:** Google Colab
# **Tools:** JavaScript + p5.js
#
# ### Fokus Praktikum
#
# Membangun visual 2D dari **primitive shapes**.
#
# Pada pertemuan ini mahasiswa belajar:
#
# **Observe → Decompose → Coordinate → Implement → Compare → Refine**

# %% [markdown]
# ---
# ## 🎯 Capaian Pembelajaran
#
# ### CPMK-1
# Mampu menjelaskan konsep dasar grafika komputer, pixel, warna, resolusi, frame rate, transformasi 2D/3D, vektor, matriks, koordinat, dan graphics pipeline.
#
# ### Sub-CPMK Pertemuan 3
# Mahasiswa mampu **mengimplementasikan primitive shapes 2D dan sistem koordinat untuk membangun objek visual sederhana menggunakan p5.js**.
#
# ### Bukti Capaian
# Mahasiswa menghasilkan:
# - 3 **Latihan Terbimbing**
# - 7 **Latihan Mandiri**
# - 2 **Soal Pengayaan**
# - screenshot hasil program
# - dokumentasi primitive yang digunakan

# %% [markdown]
# ---
# # 1. 🧠 Primitive Shapes
#
# Pada praktikum ini **hanya gunakan primitive shapes berikut**:
#
# | Primitive | Fungsi |
# |---|---|
# | `point()` | Titik |
# | `line()` | Garis |
# | `rect()` | Persegi / persegi panjang |
# | `circle()` | Lingkaran |
# | `ellipse()` | Elips |
# | `triangle()` | Segitiga |
#
# ### Aturan praktikum
#
# ❌ Tidak menggunakan `image()`
# ❌ Tidak menggunakan gambar eksternal
# ❌ Tidak menggunakan asset sprite
# ❌ Tidak menggunakan library grafika lain
#
# ✅ Visual harus dibangun dari primitive shapes.
#
# ### Prinsip utama
#
# > **Satu objek kompleks dapat dibangun dari beberapa primitive sederhana.**

# %% [markdown]
# # 2. 📐 Sistem Koordinat p5.js
#
# Canvas menggunakan sistem koordinat:
#
# ```text
# (0,0)
#   ┌──────────────────────────────→ X
#   │
#   │
#   │
#   ↓
#   Y
# ```
#
# - `x` semakin besar → bergerak ke kanan.
# - `y` semakin besar → bergerak ke bawah.
#
# Contoh:
#
# ```javascript
# p.rect(30, 20, 55, 55);
# ```
#
# Artinya:
# - X = 30
# - Y = 20
# - lebar = 55
# - tinggi = 55
#
# ### Pola kerja
#
# 1. Tentukan posisi.
# 2. Tentukan ukuran.
# 3. Pilih primitive.
# 4. Tentukan warna.
# 5. Susun primitive menjadi objek.

# %% [markdown]
# # 3. 💻 Template p5.js yang Digunakan
#
# Notebook ini menggunakan formulasi **FIX** yang sudah Anda temukan.
#
# Mahasiswa cukup fokus pada bagian:
#
# ```javascript
# // KODE MAHASISWA
# ```
#
# dan menggunakan fungsi p5.js dengan awalan `p.`.
#
# Contoh:
#
# ```javascript
# p.rect(30, 20, 55, 55);
# p.circle(150, 100, 80);
# p.line(200, 100, 300, 150);
# ```
#
# > Struktur wrapper Google Colab tidak perlu dipelajari mahasiswa. Fokus pembelajaran tetap pada primitive shapes dan koordinat.

# %% [markdown]
# ---
# # 🟢 LATIHAN TERBIMBING 1 — Matahari
#
# ## Tujuan
# Memahami cara kerja:
# - `circle()`
# - `line()`
# - koordinat
# - ukuran
# - warna
#
# ### Cara berpikir
#
# Matahari dapat dipecah menjadi:
#
# ```text
# Matahari
# ├── circle() → pusat
# └── line()   → sinar
# ```
#
# Ikuti contoh kode berikut terlebih dahulu.

# %%
# %%html
# <script src="https://cdnjs.cloudflare.com/ajax/libs/p5.js/1.11.1/p5.min.js"></script>
#
# <div id="contoh_matahari"></div>
#
# <script>
# new p5(function(p) {
#
#   p.setup = function() {
#     p.createCanvas(800, 500);
#   };
#
#   p.draw = function() {
#     p.background(235);
#
#
#     // =====================================
#     // CONTOH 1 — MATAHARI
#     // =====================================
#
#     p.fill(255, 200, 0);
#     p.noStroke();
#     p.circle(400, 250, 120);
#
#     p.stroke(255, 180, 0);
#     p.strokeWeight(5);
#
#     p.line(400, 160, 400, 100);
#     p.line(400, 340, 400, 400);
#     p.line(310, 250, 250, 250);
#     p.line(490, 250, 550, 250);
#
#     p.line(336, 186, 294, 144);
#     p.line(464, 186, 506, 144);
#     p.line(336, 314, 294, 356);
#     p.line(464, 314, 506, 356);
#
#   };
#
# }, 'contoh_matahari');
# </script>
# Out:
# <script src="https://cdnjs.cloudflare.com/ajax/libs/p5.js/1.11.1/p5.min.js"></script>
#
# <div id="contoh_matahari"></div>
#
# <script>
# new p5(function(p) {
#
#   p.setup = function() {
#     p.createCanvas(800, 500);
#   };
#
#   p.draw = function() {
#     p.background(235);
#
#
#     // =====================================
#     // CONTOH 1 — MATAHARI
#     // =====================================
#
#     // Pusat matahari
#     p.fill(255, 200, 0);
#     p.noStroke();
#     p.circle(400, 250, 120);
#
#     // Sinar matahari
#     p.stroke(255, 180, 0);
#     p.strokeWeight(5);
#
#     p.line(400, 160, 400, 100);
#     p.line(400, 340, 400, 400);
#     p.line(310, 250, 250, 250);
#     p.line(490, 250, 550, 250);
#
#     p.line(336, 186, 294, 144);
#     p.line(464, 186, 506, 144);
#     p.line(336, 314, 294, 356);
#     p.line(464, 314, 506, 356);
#
#   };
#
# }, 'contoh_matahari');
# </script>

# %% [markdown]
# ### 🔎 Bedah Kode
#
# Perhatikan:
#
# ```javascript
# p.circle(400, 250, 120);
# ```
#
# `400` = X
# `250` = Y
# `120` = diameter
#
# Sedangkan:
#
# ```javascript
# p.line(x1, y1, x2, y2);
# ```
#
# digunakan untuk menghubungkan dua titik.
#
# ### Eksperimen
#
# Sebelum membuat ulang:
# 1. Ubah posisi matahari.
# 2. Ubah ukuran matahari.
# 3. Ubah warna matahari.
# 4. Tambahkan satu sinar.
# 5. Hapus satu sinar dan amati perubahan visual.

# %% [markdown]
# ### ✏️ Tugas Latihan 1
#
# Buat ulang matahari **tanpa menyalin kode contoh**.
#
# Ketentuan:
# - gunakan minimal 1 `circle()`;
# - gunakan minimal 8 `line()`;
# - tentukan sendiri koordinatnya;
# - gunakan warna sendiri.

# %%
# %%html
# <script src="https://cdnjs.cloudflare.com/ajax/libs/p5.js/1.11.1/p5.min.js"></script>
#
# <div id="latihan_1_matahari"></div>
#
# <script>
# new p5(function(p) {
#
#   p.setup = function() {
#     p.createCanvas(800, 500);
#   };
#
#   p.draw = function() {
#     p.background(235);
#
#
#     // =====================================
#     // LATIHAN 1 — KODE MAHASISWA
#     // =====================================
#
#     // Tulis ulang matahari dengan kode Anda sendiri.
#
#   };
#
# }, 'latihan_1_matahari');
# </script>
# Out:
# <script src="https://cdnjs.cloudflare.com/ajax/libs/p5.js/1.11.1/p5.min.js"></script>
#
# <div id="latihan_1_matahari"></div>
#
# <script>
# new p5(function(p) {
#
#   p.setup = function() {
#     p.createCanvas(800, 500);
#   };
#
#   p.draw = function() {
#     p.background(235);
#
#
#     // =====================================
#     // LATIHAN 1 — KODE MAHASISWA
#     // =====================================
#
#     // Tulis ulang matahari dengan kode Anda sendiri.
#
#   };
#
# }, 'latihan_1_matahari');
# </script>

# %% [markdown]
# ---
# # 🟢 LATIHAN TERBIMBING 2 — Rumah
#
# ## Tujuan
# Memahami bahwa satu objek dapat dibangun dari beberapa primitive.
#
# ### Hints
#
# ```text
# Rumah
# ├── triangle() → atap
# ├── rect()     → badan
# ├── rect()     → pintu
# └── rect()     → jendela
# ```
#
# Perhatikan contoh berikut.

# %%
# %%html
# <script src="https://cdnjs.cloudflare.com/ajax/libs/p5.js/1.11.1/p5.min.js"></script>
#
# <div id="contoh_rumah"></div>
#
# <script>
# new p5(function(p) {
#
#   p.setup = function() {
#     p.createCanvas(800, 500);
#   };
#
#   p.draw = function() {
#     p.background(235);
#
#
#     // =====================================
#     // CONTOH 2 — RUMAH
#     // =====================================
#
#
#     p.noStroke();
#     p.fill(90, 170, 90);
#     p.rect(0, 390, 800, 110);
#
#
#     p.fill(230, 180, 120);
#     p.rect(280, 220, 240, 170);
#
#
#     p.fill(160, 70, 60);
#     p.triangle(
#       250, 220,
#       400, 100,
#       550, 220
#     );
#
#
#     p.fill(100, 60, 40);
#     p.rect(370, 300, 60, 90);
#
#
#     p.fill(120, 200, 230);
#     p.rect(305, 260, 45, 45);
#     p.rect(450, 260, 45, 45);
#
#   };
#
# }, 'contoh_rumah');
# </script>
# Out:
# <script src="https://cdnjs.cloudflare.com/ajax/libs/p5.js/1.11.1/p5.min.js"></script>
#
# <div id="contoh_rumah"></div>
#
# <script>
# new p5(function(p) {
#
#   p.setup = function() {
#     p.createCanvas(800, 500);
#   };
#
#   p.draw = function() {
#     p.background(235);
#
#
#     // =====================================
#     // CONTOH 2 — RUMAH
#     // =====================================
#
#
#     p.noStroke();
#     p.fill(90, 170, 90);
#     p.rect(0, 390, 800, 110);
#
#
#     p.fill(230, 180, 120);
#     p.rect(280, 220, 240, 170);
#
#
#     p.fill(160, 70, 60);
#     p.triangle(
#       250, 220,
#       400, 100,
#       550, 220
#     );
#
#
#     p.fill(100, 60, 40);
#     p.rect(370, 300, 60, 90);
#
#
#     p.fill(120, 200, 230);
#     p.rect(305, 260, 45, 45);
#     p.rect(450, 260, 45, 45);
#
#   };
#
# }, 'contoh_rumah');
# </script>

# %% [markdown]
# ### 🔎 Bedah Kode
#
# Perhatikan `triangle()`:
#
# ```javascript
# p.triangle(
#   x1, y1,
#   x2, y2,
#   x3, y3
# );
# ```
#
# Tiga titik tersebut membentuk atap.
#
# ### Eksperimen
#
# 1. Geser rumah ke kanan.
# 2. Perbesar atap.
# 3. Ubah tinggi pintu.
# 4. Tambahkan satu jendela.
# 5. Ubah warna rumah.
#
# **Perhatikan:** perubahan koordinat satu primitive dapat mengubah proporsi seluruh objek.

# %% [markdown]
# ### ✏️ Tugas Latihan 2
#
# Buat ulang rumah dengan desain Anda sendiri.
#
# Ketentuan:
# - minimal 1 `triangle()`;
# - minimal 4 `rect()`;
# - rumah harus memiliki atap, badan, pintu, dan jendela;
# - jangan menyalin koordinat contoh.

# %%
# %%html
# <script src="https://cdnjs.cloudflare.com/ajax/libs/p5.js/1.11.1/p5.min.js"></script>
#
# <div id="latihan_2_rumah"></div>
#
# <script>
# new p5(function(p) {
#
#   p.setup = function() {
#     p.createCanvas(800, 500);
#   };
#
#   p.draw = function() {
#     p.background(235);
#
#
#     // =====================================
#     // LATIHAN 2 — KODE MAHASISWA
#     // =====================================
#
#     // Tulis kode rumah Anda sendiri.
#
#   };
#
# }, 'latihan_2_rumah');
# </script>
# Out:
# <script src="https://cdnjs.cloudflare.com/ajax/libs/p5.js/1.11.1/p5.min.js"></script>
#
# <div id="latihan_2_rumah"></div>
#
# <script>
# new p5(function(p) {
#
#   p.setup = function() {
#     p.createCanvas(800, 500);
#   };
#
#   p.draw = function() {
#     p.background(235);
#
#
#     // =====================================
#     // LATIHAN 2 — KODE MAHASISWA
#     // =====================================
#
#     // Tulis kode rumah Anda sendiri.
#
#   };
#
# }, 'latihan_2_rumah');
# </script>

# %% [markdown]
# ---
# # 🟢 LATIHAN TERBIMBING 3 — Pohon
#
# ## Tujuan
# Memahami konsep:
#
# > **Satu objek = kumpulan primitive yang disusun bersama.**
#
# ### Cara berpikir
#
# ```text
# Pohon
# ├── rect()       → batang
# ├── circle()     → daun
# ├── circle()     → daun
# └── circle()     → daun
# ```
#
# Ikuti contoh berikut.

# %%
# %%html
# <script src="https://cdnjs.cloudflare.com/ajax/libs/p5.js/1.11.1/p5.min.js"></script>
#
# <div id="contoh_pohon"></div>
#
# <script>
# new p5(function(p) {
#
#   p.setup = function() {
#     p.createCanvas(800, 500);
#   };
#
#   p.draw = function() {
#     p.background(235);
#
#
#     // =====================================
#     // CONTOH 3 — POHON
#     // =====================================
#
#
#     p.noStroke();
#     p.fill(90, 170, 90);
#     p.rect(0, 390, 800, 110);
#
#
#     p.fill(120, 75, 40);
#     p.rect(370, 250, 60, 140);
#
#
#     p.fill(50, 160, 70);
#     p.circle(350, 220, 110);
#     p.circle(420, 210, 130);
#     p.circle(480, 235, 105);
#     p.circle(395, 160, 120);
#
#   };
#
# }, 'contoh_pohon');
# </script>
# Out:
# <script src="https://cdnjs.cloudflare.com/ajax/libs/p5.js/1.11.1/p5.min.js"></script>
#
# <div id="contoh_pohon"></div>
#
# <script>
# new p5(function(p) {
#
#   p.setup = function() {
#     p.createCanvas(800, 500);
#   };
#
#   p.draw = function() {
#     p.background(235);
#
#
#     // =====================================
#     // CONTOH 3 — POHON
#     // =====================================
#
#
#     p.noStroke();
#     p.fill(90, 170, 90);
#     p.rect(0, 390, 800, 110);
#
#
#     p.fill(120, 75, 40);
#     p.rect(370, 250, 60, 140);
#
#
#     p.fill(50, 160, 70);
#     p.circle(350, 220, 110);
#     p.circle(420, 210, 130);
#     p.circle(480, 235, 105);
#     p.circle(395, 160, 120);
#
#   };
#
# }, 'contoh_pohon');
# </script>

# %% [markdown]
# ### 🔎 Bedah Kode
#
# Tidak ada fungsi:
#
# ```javascript
# p.tree();
# ```
#
# Pohon dibuat dengan menggabungkan primitive.
#
# Coba ubah satu `circle()`.
#
# Apa yang terjadi?
#
# ### Eksperimen
#
# 1. Geser satu daun.
# 2. Perbesar satu daun.
# 3. Tambahkan satu daun.
# 4. Ganti salah satu `circle()` menjadi `ellipse()`.
# 5. Ubah warna tajuk.

# %% [markdown]
# ### ✏️ Tugas Latihan 3
#
# Buat ulang sebuah pohon dengan desain Anda sendiri.
#
# Ketentuan:
# - minimal 1 `rect()` untuk batang;
# - minimal 3 `circle()` atau `ellipse()` untuk daun;
# - boleh menambahkan `triangle()` atau `line()` sebagai detail;
# - tidak menggunakan image.

# %%
# %%html
# <script src="https://cdnjs.cloudflare.com/ajax/libs/p5.js/1.11.1/p5.min.js"></script>
#
# <div id="latihan_3_pohon"></div>
#
# <script>
# new p5(function(p) {
#
#   p.setup = function() {
#     p.createCanvas(800, 500);
#   };
#
#   p.draw = function() {
#     p.background(235);
#
#
#     // =====================================
#     // LATIHAN 3 — KODE MAHASISWA
#     // =====================================
#
#     // Tulis kode pohon Anda sendiri.
#
#   };
#
# }, 'latihan_3_pohon');
# </script>
# Out:
# <script src="https://cdnjs.cloudflare.com/ajax/libs/p5.js/1.11.1/p5.min.js"></script>
#
# <div id="latihan_3_pohon"></div>
#
# <script>
# new p5(function(p) {
#
#   p.setup = function() {
#     p.createCanvas(800, 500);
#   };
#
#   p.draw = function() {
#     p.background(235);
#
#
#     // =====================================
#     // LATIHAN 3 — KODE MAHASISWA
#     // =====================================
#
#     // Tulis kode pohon Anda sendiri.
#
#   };
#
# }, 'latihan_3_pohon');
# </script>

# %% [markdown]
# ---
# # 🔵 LATIHAN 4 — Mobil 2D
#
#
# Buat sebuah mobil 2D dari primitive shapes.
#
# **Wajib:**
# - `rect()` → body
# - `rect()` / `triangle()` → cabin
# - `circle()` → minimal 2 roda
#
# **Fokus:** proporsi dan alignment.
#
#
# ### Langkah pengerjaan
#
# 1. Amati target/ide visual.
# 2. Pecah objek menjadi primitive.
# 3. Tentukan koordinat.
# 4. Tentukan ukuran.
# 5. Tentukan warna.
# 6. Tulis kode.
# 7. Jalankan program.
# 8. Bandingkan hasil.
# 9. Perbaiki posisi atau ukuran yang belum tepat.
# 10. Simpan screenshot hasil akhir.
#
# ### Batasan
#
# Gunakan **hanya**:
#
# `point()` • `line()` • `rect()` • `circle()` • `ellipse()` • `triangle()`

# %%
# %%html
# <script src="https://cdnjs.cloudflare.com/ajax/libs/p5.js/1.11.1/p5.min.js"></script>
#
# <div id="latihan_mandiri_4_mobil_2d"></div>
#
# <script>
# new p5(function(p) {
#
#   p.setup = function() {
#     p.createCanvas(800, 500);
#   };
#
#   p.draw = function() {
#     p.background(235);
#
#
#     // =====================================
#     // LATIHAN — KODE MAHASISWA
#     // =====================================
#
#     // Tulis kode Anda di sini.
#
#   };
#
# }, 'latihan_mandiri_4_mobil_2d');
# </script>

# %% [markdown]
# ---
# # 🔵 LATIHAN 5 — Robot Game
#
#
# Buat karakter robot sederhana.
#
# **Wajib:**
# - `rect()` → kepala dan badan
# - `circle()` / `ellipse()` → mata
# - `line()` / `rect()` → tangan dan kaki
#
# **Fokus:** beberapa primitive membentuk satu karakter.
#
#
# ### Langkah pengerjaan
#
# 1. Amati target/ide visual.
# 2. Pecah objek menjadi primitive.
# 3. Tentukan koordinat.
# 4. Tentukan ukuran.
# 5. Tentukan warna.
# 6. Tulis kode.
# 7. Jalankan program.
# 8. Bandingkan hasil.
# 9. Perbaiki posisi atau ukuran yang belum tepat.
# 10. Simpan screenshot hasil akhir.
#
# ### Batasan
#
# Gunakan **hanya**:
#
# `point()` • `line()` • `rect()` • `circle()` • `ellipse()` • `triangle()`

# %%
# %%html
# <script src="https://cdnjs.cloudflare.com/ajax/libs/p5.js/1.11.1/p5.min.js"></script>
#
# <div id="latihan_mandiri_5_robot_game"></div>
#
# <script>
# new p5(function(p) {
#
#   p.setup = function() {
#     p.createCanvas(800, 500);
#   };
#
#   p.draw = function() {
#     p.background(235);
#
#
#     // =====================================
#     // LATIHAN — KODE MAHASISWA
#     // =====================================
#
#     // Tulis kode Anda di sini.
#
#   };
#
# }, 'latihan_mandiri_5_robot_game');
# </script>

# %% [markdown]
# ---
# # 🔵 LATIHAN 6 — Coin Collectible
#
#
# Buat sebuah collectible coin.
#
# **Wajib:**
# - `circle()` → bentuk utama
# - `ellipse()` atau `circle()` → detail
# - gunakan warna yang membuat item mudah dikenali.
#
# **Fokus:** readability sebagai objek game.
#
#
# ### Langkah pengerjaan
#
# 1. Amati target/ide visual.
# 2. Pecah objek menjadi primitive.
# 3. Tentukan koordinat.
# 4. Tentukan ukuran.
# 5. Tentukan warna.
# 6. Tulis kode.
# 7. Jalankan program.
# 8. Bandingkan hasil.
# 9. Perbaiki posisi atau ukuran yang belum tepat.
# 10. Simpan screenshot hasil akhir.
#
# ### Batasan
#
# Gunakan **hanya**:
#
# `point()` • `line()` • `rect()` • `circle()` • `ellipse()` • `triangle()`

# %%
# %%html
# <script src="https://cdnjs.cloudflare.com/ajax/libs/p5.js/1.11.1/p5.min.js"></script>
#
# <div id="latihan_mandiri_6_coin_collectible"></div>
#
# <script>
# new p5(function(p) {
#
#   p.setup = function() {
#     p.createCanvas(800, 500);
#   };
#
#   p.draw = function() {
#     p.background(235);
#
#
#     // =====================================
#     // LATIHAN — KODE MAHASISWA
#     // =====================================
#
#     // Tulis kode Anda di sini.
#
#   };
#
# }, 'latihan_mandiri_6_coin_collectible');
# </script>

# %% [markdown]
# ---
# # 🔵 LATIHAN 7 — Pedang Game
#
#
# Buat sebuah pedang menggunakan primitive.
#
# **Wajib:**
# - `triangle()` atau kombinasi bentuk untuk bilah
# - `rect()` → handle
# - `line()` / `rect()` → guard
#
# **Fokus:** menyusun primitive pada satu arah/sumbu.
#
#
# ### Langkah pengerjaan
#
# 1. Amati target/ide visual.
# 2. Pecah objek menjadi primitive.
# 3. Tentukan koordinat.
# 4. Tentukan ukuran.
# 5. Tentukan warna.
# 6. Tulis kode.
# 7. Jalankan program.
# 8. Bandingkan hasil.
# 9. Perbaiki posisi atau ukuran yang belum tepat.
# 10. Simpan screenshot hasil akhir.
#
# ### Batasan
#
# Gunakan **hanya**:
#
# `point()` • `line()` • `rect()` • `circle()` • `ellipse()` • `triangle()`

# %%
# %%html
# <script src="https://cdnjs.cloudflare.com/ajax/libs/p5.js/1.11.1/p5.min.js"></script>
#
# <div id="latihan_mandiri_7_pedang_game"></div>
#
# <script>
# new p5(function(p) {
#
#   p.setup = function() {
#     p.createCanvas(800, 500);
#   };
#
#   p.draw = function() {
#     p.background(235);
#
#
#     // =====================================
#     // LATIHAN — KODE MAHASISWA
#     // =====================================
#
#     // Tulis kode Anda di sini.
#
#   };
#
# }, 'latihan_mandiri_7_pedang_game');
# </script>

# %% [markdown]
# ---
# # 🔵 LATIHAN 8 — Karakter Alien
#
#
# Buat karakter alien sederhana.
#
# **Wajib:**
# - `ellipse()` → kepala
# - minimal 2 bentuk untuk mata
# - primitive lain untuk badan dan anggota tubuh.
#
# **Fokus:** siluet karakter.
#
#
# ### Langkah pengerjaan
#
# 1. Amati target/ide visual.
# 2. Pecah objek menjadi primitive.
# 3. Tentukan koordinat.
# 4. Tentukan ukuran.
# 5. Tentukan warna.
# 6. Tulis kode.
# 7. Jalankan program.
# 8. Bandingkan hasil.
# 9. Perbaiki posisi atau ukuran yang belum tepat.
# 10. Simpan screenshot hasil akhir.
#
# ### Batasan
#
# Gunakan **hanya**:
#
# `point()` • `line()` • `rect()` • `circle()` • `ellipse()` • `triangle()`

# %%
# %%html
# <script src="https://cdnjs.cloudflare.com/ajax/libs/p5.js/1.11.1/p5.min.js"></script>
#
# <div id="latihan_mandiri_8_karakter_alien"></div>
#
# <script>
# new p5(function(p) {
#
#   p.setup = function() {
#     p.createCanvas(800, 500);
#   };
#
#   p.draw = function() {
#     p.background(235);
#
#
#     // =====================================
#     // LATIHAN — KODE MAHASISWA
#     // =====================================
#
#     // Tulis kode Anda di sini.
#
#   };
#
# }, 'latihan_mandiri_8_karakter_alien');
# </script>
